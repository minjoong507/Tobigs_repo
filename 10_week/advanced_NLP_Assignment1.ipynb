# %% [markdown]
# # 영화 리뷰 감정 분류
#
# #### 10주 동안 고생많았습니다. 한 주만 더 고생해주세요
#
# * Data : ratings.txt
# * 아래 기입된 요구사항에 맞춰서 ipynb파일을 완성시켜주시기 바랍니다.
# * 모든 요구사항에 부합해야 과제 제출 인정하겠습니다.
#
# ##### 1st Task : Machine Learning Classifier ( Sklearn )
# ##### 2nd Task : Deep Learning model Classifier ( PyTorch or Tensorflow )

# %% [markdown]
# ### 데이터 전처리
#
# * 원천 데이터는 '\t'로 구분된 User id, 리뷰 내용, 긍/부정 데이터가 각 행마다 적재되어 있습니다.
# * 긍정은 1로 표기되어 있고, 부정은 0으로 표기되어 있습니다.
#
# #### 아래의 이미지 형식을 맞춰주시기 바랍니다.
#
# 리뷰 데이터를 여시면 다음과 같이 출력됩니다
# ```python
# with open('ratings.txt', 'r', encoding='utf-8') as f:
#     text = f.readlines()
# ```
#
# ![step1_before.PNG](attachment:step1_before.PNG)
# <br>
# <br>
# 이를 데이터프레임에 올바르게 구분지어 head() 출력해주세요
#
# ![step1_after.PNG](attachment:step1_after.PNG)

# %%
'''
// TODO : 원천 데이터를 데이터프레임에 적재해주세요





'''

# %% [markdown]
# ### Embedding
#
# * 모든 리뷰 데이터를 토크나이징 해주세요. Konlpy, Khaiii 상관없이 자유롭게 선택하세요.
#
# > '어릴때보고 지금다시봐도 재밌어요ㅋㅋ' \
# > → ['어릴', '때', '보고', '지금', '다시', '봐도', '재밌어요', 'ㅋㅋ']
#
# * 원-핫 임베딩, 빈도 기반 임베딩, Word2Vec, FastText 등 자유롭게 한 가지를 선택하고 말뭉치에 임베딩을 적용해주세요
#     * 임베딩을 도와줄 라이브러리들
#     * 원-핫 : Sklearn의 CountVectorizer (※ 문장이 하나의 String이어야 합니다)
#         * 원-핫 임베딩 시 메모리 부족 현상이 나타날 수 있습니다. 최대 문장길이를 제한하거나 학습 데이터 양을 줄이시면 해결됩니다
#     * Word2Vec : Gensim (※ 문장이 하나의 List이어야 합니다)
#     * FastText : FastText
#
#
# ![step2.PNG](attachment:step2.PNG)

# %%
'''
//TODO : 토크나이징과 임베딩을 진행하세요

'''

# %% [markdown]
# ### Task 1. 머신러닝 분류기 모델 만들기
#
# * 그 동안 투빅스에서 배운 어느 분류기든 상관없습니다. 주어진 데이터를 학습하고 분류해주세요
#
# ![ml.PNG](attachment:ml.PNG)
#
#
# * Cross Validation을 반드시 해주세요
# * Sklearn의 auc score를 출력해서 모델의 성능을 평가해주세요
#     * TypeError가 난다면 정답 데이터의 data type을 확인해보세요
#
#
# ![roc.PNG](attachment:roc.PNG)

# %% [markdown]
# ### Task 2. 딥러닝 분류기 모델 만들기
#
# * Tensorflow 또는 PyTorch 등을 사용하여 분류기를 만들어주세요
# * 각 프레임워크 별로 RNN 튜토리얼이 자세하게 준비되어있습니다. 구글링 ㄱㄱ
# * Task 1과 동일하게 평가지표를 출력해주시기 바랍니다

# %%
'''
// TODO : 딥러닝 분류기 만들기 

제 로컬은 GPU가 없어요. 예시 못보여줘서 미안합니다ㅠ

'''

# %% [markdown]
# #### 데이터 출처
# https://github.com/e9t/nsmc/
