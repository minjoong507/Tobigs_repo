# %%
cd /content/drive/My Drive/FireFriday
# Out:
# /content/drive/My Drive/FireFriday

# %%
import pandas as pd
import numpy as np

# %%
# !pip install -q tensorflow-gpu==2.0.0-rc1
# Out:
#      |████████████████████████████████| 380.5MB 43kB/s
#      |████████████████████████████████| 501kB 35.7MB/s
#      |████████████████████████████████| 4.3MB 34.7MB/s

# %%
sample_submission = pd.read_csv("sample_submission.csv")
train = pd.read_csv("train_df.csv")
test = pd.read_csv("test_df.csv")

# %%
train.head()
# Out:
#    label  pixel0  pixel1  pixel2  ...  pixel780  pixel781  pixel782  pixel783
# 0      7       0       0       0  ...         0         0         0         0
# 1      8       0       0       0  ...         0         0         0         0
# 2      7       0       0       0  ...         0         0         0         0
# 3      6       0       0       0  ...         0         0         0         0
# 4      5       0       0       0  ...         0         0         0         0
#
# [5 rows x 785 columns]

# %%
test.head()
# Out:
#    Unnamed: 0  pixel0  pixel1  pixel2  ...  pixel780  pixel781  pixel782  pixel783
# 0       57808       0       0       0  ...         0         0         0         0
# 1        4960       0       0       0  ...         0         0         0         0
# 2       35755       0       0       0  ...         0         0         0         0
# 3       15543       0       0       0  ...         0         0         0         0
# 4       48968       0       0       0  ...         0         0         0         0
#
# [5 rows x 785 columns]

# %%
X = train.iloc[:,1:].values
y = train.iloc[:,0].values

# %%
X_test = test.iloc[:,1:].values

# %%
X = X / 255
X_test = X_test / 255

# %%
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=2018)

# %%
print(x_train.shape, x_val.shape, y_train.shape, y_val.shape)
# Out:
# (33600, 784) (8400, 784) (33600,) (8400,)

# %%
import matplotlib.pyplot as plt
idx = 1000
plt.imshow(x_train[idx].reshape(28, 28), cmap="gray")

# %%
import tensorflow as tf
num_classes = 10
model = tf.keras.models.Sequential([
  tf.keras.layers.Dense(64, input_shape=(784,)),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(128, activation="selu"),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(256, activation="selu"),
  tf.keras.layers.Dense(num_classes, activation="softmax"),
])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/backend.py:4268: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
# !pip install keras-rectified-adam
# Out:
# Collecting keras-rectified-adam
#   Downloading https://files.pythonhosted.org/packages/21/79/9521f66b92186702cb58a214c1b923b416266381cd824e15a1733f6a5b06/keras-rectified-adam-0.17.0.tar.gz
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from keras-rectified-adam) (1.17.5)
# Requirement already satisfied: Keras in /usr/local/lib/python3.6/dist-packages (from keras-rectified-adam) (2.2.5)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from Keras->keras-rectified-adam) (1.0.8)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from Keras->keras-rectified-adam) (1.4.1)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from Keras->keras-rectified-adam) (1.1.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from Keras->keras-rectified-adam) (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from Keras->keras-rectified-adam) (2.8.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from Keras->keras-rectified-adam) (1.12.0)
# Building wheels for collected packages: keras-rectified-adam
#   Building wheel for keras-rectified-adam (setup.py) ... done
#   Created wheel for keras-rectified-adam: filename=keras_rectified_adam-0.17.0-cp36-none-any.whl size=14781 sha256=e9fd1288a27aca3c376762ed57186c34444257a4cfd028189a5826982270b102
#   Stored in directory: /root/.cache/pip/wheels/7b/01/27/3a934e1a5644f5b93c720422a6ef97034ea78a21ba71cfb549
# Successfully built keras-rectified-adam
# Installing collected packages: keras-rectified-adam
# Successfully installed keras-rectified-adam-0.17.0

# %%
class myAccuracy(tf.keras.metrics.Accuracy):
    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = tf.argmax(y_true,1)
        y_pred = tf.argmax(y_pred,1)
        return super(myAccuracy,self).update_state(y_true,y_pred,sample_weight)

# %%
from keras_radam.training import RAdamOptimizer
model.compile(optimizer=RAdamOptimizer(), loss="sparse_categorical_crossentropy", metrics=[myAccuracy()])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                50240
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64)                256
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               8320
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 94,922
# Trainable params: 94,538
# Non-trainable params: 384
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, 
                    batch_size=512, epochs=20, 
                    validation_data=[x_val, y_val])
# Out:
# Train on 33600 samples, validate on 8400 samples
# Epoch 1/20
# 33600/33600 [==============================] - 2s 46us/sample - loss: 0.0268 - accuracy: 0.0994 - val_loss: 0.0894 - val_accuracy: 0.0996
# Epoch 2/20
# 33600/33600 [==============================] - 1s 26us/sample - loss: 0.0249 - accuracy: 0.1002 - val_loss: 0.0898 - val_accuracy: 0.0999
# Epoch 3/20
# 33600/33600 [==============================] - 1s 25us/sample - loss: 0.0259 - accuracy: 0.0998 - val_loss: 0.0895 - val_accuracy: 0.0999
# Epoch 4/20
# 33600/33600 [==============================] - 1s 25us/sample - loss: 0.0242 - accuracy: 0.0996 - val_loss: 0.0965 - val_accuracy: 0.0993
# Epoch 5/20
# 33600/33600 [==============================] - 1s 26us/sample - loss: 0.0261 - accuracy: 0.1001 - val_loss: 0.0932 - val_accuracy: 0.0996
# Epoch 6/20
# 33600/33600 [==============================] - 1s 26us/sample - loss: 0.0248 - accuracy: 0.0999 - val_loss: 0.0931 - val_accuracy: 0.0996
# Epoch 7/20
# 33600/33600 [==============================] - 1s 28us/sample - loss: 0.0265 - accuracy: 0.1001 - val_loss: 0.0938 - val_accuracy: 0.0995
# Epoch 8/20
# 33600/33600 [==============================] - 1s 27us/sample - loss: 0.0261 - accuracy: 0.0997 - val_loss: 0.0922 - val_accuracy: 0.0992
# Epoch 9/20
# 33600/33600 [==============================] - 1s 27us/sample - loss: 0.0236 - accuracy: 0.0999 - val_loss: 0.0949 - val_accuracy: 0.0983
# Epoch 10/20
# 33600/33600 [==============================] - 1s 26us/sample - loss: 0.0234 - accuracy: 0.0996 - val_loss: 0.0916 - val_accuracy: 0.0993
# Epoch 11/20
# 33600/33600 [==============================] - 1s 28us/sample - loss: 0.0247 - accuracy: 0.1000 - val_loss: 0.0928 - val_accuracy: 0.0986
# Epoch 12/20
# 33600/33600 [==============================] - 1s 26us/sample - loss: 0.0286 - accuracy: 0.1002 - val_loss: 0.0875 - val_accuracy: 0.0988
# Epoch 13/20
# 33600/33600 [==============================] - 1s 25us/sample - loss: 0.0251 - accuracy: 0.0998 - val_loss: 0.0865 - val_accuracy: 0.0995
# Epoch 14/20
# 33600/33600 [==============================] - 1s 26us/sample - loss: 0.0242 - accuracy: 0.1000 - val_loss: 0.0872 - val_accuracy: 0.0995
# Epoch 15/20
# 33600/33600 [==============================] - 1s 25us/sample - loss: 0.0256 - accuracy: 0.0998 - val_loss: 0.0912 - val_accuracy: 0.1002
# Epoch 16/20
# 33600/33600 [==============================] - 1s 25us/sample - loss: 0.0233 - accuracy: 0.0999 - val_loss: 0.0915 - val_accuracy: 0.0988
# Epoch 17/20
# 33600/33600 [==============================] - 1s 25us/sample - loss: 0.0236 - accuracy: 0.1001 - val_loss: 0.0948 - val_accuracy: 0.0990
# Epoch 18/20
# 33600/33600 [==============================] - 1s 26us/sample - loss: 0.0232 - accuracy: 0.0998 - val_loss: 0.0928 - val_accuracy: 0.0998
# Epoch 19/20
# 33600/33600 [==============================] - 1s 26us/sample - loss: 0.0224 - accuracy: 0.0997 - val_loss: 0.0936 - val_accuracy: 0.1001
# Epoch 20/20
# 33600/33600 [==============================] - 1s 26us/sample - loss: 0.0225 - accuracy: 0.1000 - val_loss: 0.0945 - val_accuracy: 0.0999

# %%
predictions = model.predict_classes(X_test)

# %%
predictions
# Out:
# array([8, 0, 5, ..., 3, 4, 1])

# %%
sample_submission.head()
# Out:
#       Id  Category
# 0  57808         0
# 1   4960         0
# 2  35755         0
# 3  15543         0
# 4  48968         0

# %%
sample_submission["Category"] = pd.Series(predictions)
sample_submission.head()
# Out:
#       Id  Category
# 0  57808         8
# 1   4960         0
# 2  35755         5
# 3  15543         3
# 4  48968         8

# %%
sample_submission.to_csv("radam_submission.csv", index=False)

# %%
fig, loss_ax = plt.subplots()
acc_ax = loss_ax.twinx()

loss_ax.plot(history.history['loss'], 'y', label='train loss')
loss_ax.plot(history.history['val_loss'], 'r', label='val loss')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
loss_ax.legend(loc='upper left')

acc_ax.plot(history.history['accuracy'], 'b', label='train acc')
acc_ax.plot(history.history['val_accuracy'], 'g', label='val acc')
acc_ax.set_ylabel('accuracy')
acc_ax.legend(loc='upper left')

plt.show()
